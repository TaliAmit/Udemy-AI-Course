# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")# Your code here
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
user_input = input("What is your name?")# Your code here
print("Hello", user_input)
# Out:
# Hello Tali

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
number = int(input("Enter a number:"))

if number > 0:
    print("The number is positive")
elif number < 0:
    print("The number is negative")
else:
    print("The number is zero")
# Out:
# The number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
def find_largest(num1, num2, num3):
    return max(num1, num2, num3)

def find_largest_from_arr(numbers):
    return max(numbers)

print(find_largest(3, 5, 2))
print(find_largest_from_arr([3, 5, 2, 8, 1]))
# Out:
# 5
# 8

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
import math

def factorial(number):
    if number >= 0:
        print(math.factorial(number))
    else:
        print("Factorial is not defined for negative numbers")   

factorial(6) 
factorial(-3) 
factorial(0)  # Your code here
# Out:
# 720
# Factorial is not defined for negative numbers
# 1

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
info = ["Tali", 32, True, 7.56]

print([type(elem) for elem in info])
print(str(info))
# Out:
# [<class 'str'>, <class 'int'>, <class 'bool'>, <class 'float'>]
# ['Tali', 32, True, 7.56]

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
def swap_two_vars(a, b):

    return b, a

x = 10
y = 20

print(x,y)
print(swap_two_vars(x, y))

x,y = y,x
print(x,y)
# Out:
# 10 20
# (20, 10)
# 20 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print(celsius, "°C =", fahrenheit, "°F")
# Out:
# 31.0 °C = 87.8 °F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
def concatenate_two_strs(str1, str2):
    return str1 + " " + str2

print(concatenate_two_strs("Hello", "World"))
# Out:
# Hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
def is_from_dtype(variable, dtype):
    return (type(variable)) == dtype

name = "Tali"
f_num = 32.8

print(is_from_dtype(name, type(f_num)))
print(is_from_dtype(name, str))
# Out:
# False
# True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
def calc(num1, num2, operator):
    try:
        num1 = float(num1)
        num2 = float(num2)
    except ValueError:
        return "Error: Invalid number input"
    
    match operator:
        case "+":
            return num1 + num2
        case "-":
            return num1 - num2 
        case "*":
            return num1 * num2
        case "/":
            if num2 != 0:
                return num1 / num2
            else:
                return "Error: Division by zero"
        case _:
            return "Error: Invalid operator"
    
a = 1
b = 2

print(calc(a,b,"+"))
print(calc(a,b,"-"))
print(calc(a,b,"*"))
print(calc(a,b,"/"))
print(calc(a,0,"/"))
print(calc(a,b,"^"))
print(calc("a",b,"+"))
# Out:
# 3.0
# -1.0
# 2.0
# 0.5
# Error: Division by zero
# Error: Invalid operator
# Error: Invalid number input

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
def comparison_numbers(num1, num2):
    if num1 > num2:
        return str(num1) + " > " + str(num2)
    elif num1 < num2:
        return f"{num1} < {num2}"
    else:
        return f"{num1} == {num2}"

num1 = -5
num2 = 3

print(comparison_numbers(num1, num2))
print(comparison_numbers(-num1, num2))  
print(comparison_numbers(num1, num2 - 8))
# Out:
# -5 < 3
# 5 > 3
# -5 == -5

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
zero = 0
one = 1

print(zero and one)
print(zero or one)
print(not zero)

f_val = False
t_val = True

print(f_val and t_val)
print(f_val or t_val)
print(not f_val)
# Out:
# 0
# 1
# True
# False
# True
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
import math

num = 9.3
print(math.sqrt(num))
# Out:
# 3.0495901363953815

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = 9.3
int_num = int(num)

if(int_num % 2 == 0):
    print(f"{int_num} is even")
else:
    print(f"{int_num} is odd")
# Out:
# 9 is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
def sum_n_naturals(n):
    if n >= 0:
        return sum(range(n+1))
        # range starts at 0 by default
        # range is exclusive of the end value

    else:
        return "Error: Input must be a non-negative integer"
    

print(sum_n_naturals(-5))
print(sum_n_naturals(0))
print(sum_n_naturals(5))
# Out:
# Error: Input must be a non-negative integer
# 0
# 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
ordered_str = "Hello"
reversed_str = ordered_str[::-1]
print(reversed_str)
# Out:
# olleH

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
def is_palindrome(s):
    # return s == s[::-1] # waste of space, awful with big strings
    return all(s[i] == s[-i-1] for i in range(len(s) // 2))

print(is_palindrome("radar"))
print(is_palindrome("hello"))

name = "Tali"
print([name[-i] for i in range(len(name) // 2)])
# when i == 0 then -i is also equals to zero
# so it gives us the resukt: [T, i]
# Out:
# ['T', 'i']
# True
# False

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
nums = [200,-3, 5, 0, -1, 8, 15]
nums.sort() # inplace

print(nums)
# Out:
# [-3, -1, 0, 5, 8, 15, 200]
